# %% [markdown]
# ## aseview viewer smoke test

# %%
from ase.build import molecule
import aseview
from IPython.display import HTML

# %%
water = molecule("H2O")
viewer = aseview.MolecularViewer(water)
html = viewer.get_html()
inline_ok = "createAtomStyleNeon" in html
inline_ok

# %%
HTML(html)
