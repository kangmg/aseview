# %%
from ase.build import molecule
from aseview import MolecularViewer, NormalViewer, OverlayViewer

# %%
from ase.build import graphene

# Create graphene sheet
graphene_sheet = graphene(size=(2, 2, 1), vacuum=5.0)

# %%
from ase.io import read 

DA_moelcules = read('test.xyz', format='xyz', index=':')
butadiene = read('butadiene.xyz', format='xyz', index=':')
mof = read('MnH28C26(N2Cl)2.cif')
mof2 = read('EDUSIF_clean.cif')
rxn1 = read('rxn1.xyz', format='xyz', index=':')
rxn2 = read('rxn2.xyz', format='xyz', index=':')
# Out:
# /Users/kangmg/compchem/aseview/.venv/lib/python3.9/site-packages/ase/io/cif.py:410: UserWarning: crystal system 'triclinic' is not interpreted for space group Spacegroup(1, setting=1). This may result in wrong setting!
#   warnings.warn(

# %%
rxn1[:3]
# Out:
# [Atoms(symbols='C27H36MnN2O5', pbc=False),
#  Atoms(symbols='C27H36MnN2O5', pbc=False),
#  Atoms(symbols='C27H36MnN2O5', pbc=False)]

# %%
viewer = MolecularViewer(rxn1)
viewer.save_html('rxn1.html')
# Out:
# Saved viewer to rxn1.html

# %%
viewer = MolecularViewer(rxn2)
viewer.save_html('rxn2.html')
# Out:
# Saved viewer to rxn2.html

# %%
viewer = MolecularViewer(mof2, style='cartoon')
viewer.show()

# %%
viewer = MolecularViewer(mof2, style='cartoon')
viewer.show()

# %%
viewer.save_html('test.html')
# Out:
# Saved viewer to test.html

# %%
dir(viewer)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_generate_html',
#  '_generate_simple_html',
#  '_get_js_data',
#  '_process_data',
#  'data',
#  'get_html',
#  'save_html',
#  'settings',
#  'show']

# %%
viewer = OverlayViewer(DA_moelcules, style='bubble')
viewer.show()
# Out:
# <div style="width: 100%; height: 600px; position: relative;">
#     <iframe
#         src="data:text/html;base64,..."
#         width="100%"
#         height="100%"
#         style="border: 1px solid #ddd; border-radius: 4px; display: block;"
#         sandbox="allow-scripts allow-same-origin"
#         scrolling="no">
#     </iframe>
# </div>
